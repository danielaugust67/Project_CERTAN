# %% [markdown]
# ## Import Package

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.feature_selection import mutual_info_classif
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('android_traffic.csv', sep=';')

df_copy = df.copy()

# %% [markdown]
# ## Baca Data dan Data Cleaned

# %%
df_cleaned = df_copy.drop(columns=['duracion', 'avg_local_pkt_rate', 'avg_remote_pkt_rate'], axis=1)


X = df_cleaned.iloc[:, :-1]
y = df_cleaned.iloc[:, -1]  # Assuming the target column is the last one

# %% [markdown]
# ## Menampilkan Kolom Data Cleaned

# %%
# Print column names for debugging
print(df_cleaned.columns)
# Out:
# Index(['name', 'tcp_packets', 'dist_port_tcp', 'external_ips', 'vulume_bytes',
#        'udp_packets', 'tcp_urg_packet', 'source_app_packets',
#        'remote_app_packets', 'source_app_bytes', 'remote_app_bytes',
#        'source_app_packets.1', 'dns_query_times', 'type'],
#       dtype='object')

# %% [markdown]
# ## Feature Selection, Encoding, dan Split Data

# %%
# Assuming df_cleaned is your DataFrame
info_gain_ratio = mutual_info_classif(X_train, y_train)

feature_names_out = encode.get_feature_names_out(input_features=X.columns)
feature_info_gain = pd.DataFrame({'Feature': feature_names_out, 'Information Gain Ratio': info_gain_ratio})

feature_info_gain = feature_info_gain.sort_values(by='Information Gain Ratio', ascending=False)

print(feature_info_gain)

# Use the top features from the mutual information analysis
top_features = feature_info_gain.head(2)['Feature'].str.replace('_0', '').str.replace('_1', '').tolist()
X = df_cleaned[top_features]
y = df_cleaned['type']  # Assuming 'type' is the target variable

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Perform inverse transform to get the original labels
y_original_labels = label_encoder.inverse_transform(y_encoded)

encode = OneHotEncoder(handle_unknown='ignore')
X_encoded = encode.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_encoded, test_size=0.2, random_state=0)

# Make predictions on the test data
y_pred = classifier.predict(X_test)
# Out:
#                        Feature  Information Gain Ratio
# 0                tcp_packets_0            7.629834e-02
# 960             vulume_bytes_0            5.796722e-02
# 929             external_ips_0            5.796722e-02
# 5615      source_app_packets_1            3.043506e-02
# 16931   source_app_packets.1_1            3.043506e-02
# ...                        ...                     ...
# 2903         vulume_bytes_6578            6.661338e-16
# 6336   source_app_packets_2490            6.661338e-16
# 6337   source_app_packets_2492            6.661338e-16
# 6338   source_app_packets_2498            6.661338e-16
# 13725    remote_app_bytes_4840            6.661338e-16
#
# [17770 rows x 2 columns]
# Confusion Matrix:
#  [[801 122]
#  [263 383]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81       923
#            1       0.76      0.59      0.67       646
#
# ...

# %% [markdown]
# ## Classifier KNN

# %%
classifier = KNeighborsClassifier(n_neighbors=39)  # You can adjust the number of neighbors

classifier.fit(X_train, y_train)

# %% [markdown]
# ## Metrik Evaluasi

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", conf_matrix)

classification_rep = classification_report(y_test, y_pred)
print("Classification Report:\n", classification_rep)

# %% [markdown]
# ## Visualisasi Metrik Evaluasi

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %% [markdown]
# ## ROC Curve

# %%
from sklearn.metrics import roc_curve, auc, precision_recall_curve

# ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test, y_pred)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='green', lw=2, label='Precision-Recall curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='upper right')
plt.show()
